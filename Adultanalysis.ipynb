# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('adult.csv')

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %% [markdown]
# # Display top 10 rows of the dataset

# %%
df.head(10)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18                 ?  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29                 ?  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %% [markdown]
# # Display Last 10 rows of the dataset

# %%
df.head(10)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18                 ?  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29                 ?  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %% [markdown]
# # Find shape of our dataset(Number of rows and columns)

# %%
df.shape
# Out:
# (48842, 15)

# %%
print("Number of Rows",df.shape[0])
print("Number of Columns",df.shape[1])
# Out:
# Number of Rows 48842
# Number of Columns 15

# %% [markdown]
# # Getting information about our dataset like total number of  rows,total number of columns,datatypes of each column and emory requirement

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %% [markdown]
# # Fetch Random Samples from the dataset (50%)

# %%
#getting random data everytime excution is being done
df.sample(frac=0.50,random_state=100)
# Out:
#        age  workclass  fnlwgt     education  educational-num  \
# 12393   37    Private  110331   Prof-school               15
# 48701   23    Private   45834     Bachelors               13
# 17918   28    Private   89718       HS-grad                9
# 11352   30    Private  351770           9th                5
# 36198   31    Private  164190          10th                6
# ...    ...        ...     ...           ...              ...
# 48573   41    Private  318046  Some-college               10
# 47252   41  Local-gov   33658  Some-college               10
# 33142   69    Private  312653  Some-college               10
# 2965    21          ?  334593  Some-college               10
# 32089   34    Private  186269       HS-grad                9
#
#            marital-status        occupation   relationship   race  gender  \
# 12393  Married-civ-spouse     Other-service           Wife  White  Female
# 48701       Never-married   Exec-managerial  Not-in-family  White  Female
# ...

# %%
df.sample(frac=0.50,random_state=110)
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 5200    42         State-gov  200294     Bachelors               13
# 24936   33           Private  172304          10th                6
# 46035   48           Private  317360  Some-college               10
# 35912   34           Private  150324     Bachelors               13
# 29903   25           Private  104097     Bachelors               13
# ...    ...               ...     ...           ...              ...
# 29585   60           Private  145995     Bachelors               13
# 21262   41           Private  252058     Bachelors               13
# 9490    39           Private  247515       HS-grad                9
# 48343   26                 ?  375313  Some-college               10
# 958     41  Self-emp-not-inc  134724     Assoc-voc               11
#
#            marital-status         occupation   relationship  \
# 5200             Divorced     Prof-specialty      Unmarried
# ...

# %% [markdown]
# # Check Null Values in the dataset

# %%
df.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
#null values column wise
df.isnull().sum(axis=0)
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
#null values row wise
df.isnull().sum(axis=1)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 48837    0
# 48838    0
# 48839    0
# 48840    0
# 48841    0
# Length: 48842, dtype: int64

# %%
#if missing is there,lighter color will be shown
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # perform data cleaning (Replace'?' with NAN' )

# %%
df.tail(30)
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 48812   30               NaN   33811     Bachelors               13
# 48813   34           Private  204461     Doctorate               16
# 48814   54           Private  337992     Bachelors               13
# 48815   37           Private  179137  Some-college               10
# 48816   22           Private  325033          12th                8
# 48817   34           Private  160216     Bachelors               13
# 48818   30           Private  345898       HS-grad                9
# 48819   38           Private  139180     Bachelors               13
# 48820   71               NaN  287372     Doctorate               16
# 48821   45         State-gov  252208       HS-grad                9
# 48822   41               NaN  202822       HS-grad                9
# 48823   72               NaN  129912       HS-grad                9
# 48824   45         Local-gov  119199    Assoc-acdm               12
# ...

# %%
df.isin(['?']).sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
#replace the ? with NAN

# %%
import numpy as np

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
df['workclass']=df['workclass'].replace('?',np.nan)
df['occupation']=df['occupation'].replace('?',np.nan)
df['native-country']=df['native-country'].replace('?',np.nan)

# %%
df.isin(['?']).sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
sns.heatmap(df.isnull())
#lighter color indicating missing values in our dataset
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Drop all the missing values

# %%
per_missing=df.isnull().sum()*100/len(df)

# %%
per_missing
#on the output we can clearly see on workclass,5% of values are missing and same for occupation and native country
# Out:
# age                0.000000
# workclass          5.730724
# fnlwgt             0.000000
# education          0.000000
# educational-num    0.000000
# marital-status     0.000000
# occupation         5.751198
# relationship       0.000000
# race               0.000000
# gender             0.000000
# capital-gain       0.000000
# capital-loss       0.000000
# hours-per-week     0.000000
# native-country     1.754637
# income             0.000000
# dtype: float64

# %%
df.dropna(how='any',inplace=True)

# %%
df.shape
# Out:
# (45222, 15)

# %%
#simple calculation to show how many rows are dropped
48842-45222
# Out:
# 3620

# %% [markdown]
# # Check for duplicate Data and drop them

# %%
dup=df.duplicated().any()

# %%
print("Are there any duplicated values in df",dup)
# Out:
# Are there any duplicated values in df True

# %%
#confirmating from the above output we have duplicated data
#next step drop them

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (45175, 15)

# %%
45222-45175
# Out:
# 47

# %% [markdown]
# # Get Overall Statistics about the dataframe

# %%
df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  45175.000000  4.517500e+04     45175.000000  45175.000000
# mean      38.556170  1.897388e+05        10.119314   1102.576270
# std       13.215349  1.056524e+05         2.551740   7510.249876
# min       17.000000  1.349200e+04         1.000000      0.000000
# 25%       28.000000  1.173925e+05         9.000000      0.000000
# 50%       37.000000  1.783120e+05        10.000000      0.000000
# 75%       47.000000  2.379030e+05        13.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  45175.000000    45175.000000
# mean      88.687593       40.942512
# std      405.156611       12.007730
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
#stastics of numerical and categorical column

# %%
#statistics of all columns
df.describe(include='all')
# Out:
#                  age workclass        fnlwgt education  educational-num  \
# count   45175.000000     45175  4.517500e+04     45175     45175.000000
# unique           NaN         7           NaN        16              NaN
# top              NaN   Private           NaN   HS-grad              NaN
# freq             NaN     33262           NaN     14770              NaN
# mean       38.556170       NaN  1.897388e+05       NaN        10.119314
# std        13.215349       NaN  1.056524e+05       NaN         2.551740
# min        17.000000       NaN  1.349200e+04       NaN         1.000000
# 25%        28.000000       NaN  1.173925e+05       NaN         9.000000
# 50%        37.000000       NaN  1.783120e+05       NaN        10.000000
# 75%        47.000000       NaN  2.379030e+05       NaN        13.000000
# max        90.000000       NaN  1.490400e+06       NaN        16.000000
#
#             marital-status    occupation relationship   race gender  \
# ...

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
df['education'].unique()
# Out:
# array(['11th', 'HS-grad', 'Assoc-acdm', 'Some-college', '10th',
#        'Prof-school', '7th-8th', 'Bachelors', 'Masters', '5th-6th',
#        'Assoc-voc', '9th', 'Doctorate', '12th', '1st-4th', 'Preschool'],
#       dtype=object)

# %%
df['educational-num'].unique()
# Out:
# array([ 7,  9, 12, 10,  6, 15,  4, 13, 14,  3, 11,  5, 16,  8,  2,  1],
#       dtype=int64)

# %% [markdown]
# # Drop the columns education-num,capital-gain and capital-loss

# %%
#both of the columns are having the same values so lets drop one of them

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
df=df.drop(['educational-num','capital-gain','capital-loss'],axis=1)

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# # What is the distribution of Age Column?

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
df['age'].describe()
# Out:
# count    45175.000000
# mean        38.556170
# std         13.215349
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         47.000000
# max         90.000000
# Name: age, dtype: float64

# %%
df['age'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Find  Total Number of Persons Having Age Between 17 to 48(inclusive using between method)

# %%
sum((df['age']>=17) & (df['age']<=48))
# Out:
# 34858

# %%
#or

# %%
sum(df['age'].between(17,48))
# Out:
# 34858

# %% [markdown]
# # What is the distribution of workclass column?

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
df['workclass'].describe()
# Out:
# count       45175
# unique          7
# top       Private
# freq        33262
# Name: workclass, dtype: object

# %%
plt.figure(figsize=(10,10))

df['workclass'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # How many Persons having Bachelors or Masters Degree?

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
filter1=df['education']=='Bachelors'
filter2=df['education']=='Masters'

# %%
df[filter1|filter2]
# Out:
#        age    workclass  fnlwgt  education  educational-num  \
# 11      36  Federal-gov  212465  Bachelors               13
# 15      43      Private  346189    Masters               14
# 20      34      Private  107914  Bachelors               13
# 23      25      Private  220931  Bachelors               13
# 24      25      Private  205947  Bachelors               13
# ...    ...          ...     ...        ...              ...
# 48817   34      Private  160216  Bachelors               13
# 48819   38      Private  139180  Bachelors               13
# 48825   31      Private  199655    Masters               14
# 48834   32      Private  116138    Masters               14
# 48835   53      Private  321865    Masters               14
#
#            marital-status       occupation   relationship                race  \
# 11     Married-civ-spouse     Adm-clerical        Husband               White
# 15     Married-civ-spouse  Exec-managerial        Husband               White
# ...

# %%
len(df[filter1|filter2])
# Out:
# 10682

# %%
sum(filter1|filter2)
# Out:
# 10682

# %%
#or

# %%
sum(df['education'].isin(['Bachelors','Masters']))
# Out:
# 10072

# %% [markdown]
# # Bivariate Analysis

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
sns.boxplot(x='income',y='age',data=df)
# Out:
# <AxesSubplot:xlabel='income', ylabel='age'>

# %% [markdown]
# # Replace income values['<=50K','>50k'] with 0 and 1

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
df['income'].unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
#find the number of values 
df['income'].value_counts()
# Out:
# <=50K    37155
# >50K     11687
# Name: income, dtype: int64

# %%
sns.countplot('income',data=df)
# Out:
# C:\Users\mohda\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='income', ylabel='count'>

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
#so lets replace the income

# %%
df.replace(to_replace=['<=50K','>50K'],value=[0,1],inplace=True)

# %%
df.head(20)
# Out:
#     age         workclass  fnlwgt     education  educational-num  \
# 0    25           Private  226802          11th                7
# 1    38           Private   89814       HS-grad                9
# 2    28         Local-gov  336951    Assoc-acdm               12
# 3    44           Private  160323  Some-college               10
# 4    18                 ?  103497  Some-college               10
# 5    34           Private  198693          10th                6
# 6    29                 ?  227026       HS-grad                9
# 7    63  Self-emp-not-inc  104626   Prof-school               15
# 8    24           Private  369667  Some-college               10
# 9    55           Private  104996       7th-8th                4
# 10   65           Private  184454       HS-grad                9
# 11   36       Federal-gov  212465     Bachelors               13
# 12   26           Private   82091       HS-grad                9
# ...

# %% [markdown]
# # Which WorkClass getting the highest Income?

# %%
df.groupby('workclass')['income'].mean().sort_values(ascending=False)
# Out:
# workclass
# Self-emp-inc        0.553392
# Federal-gov         0.391760
# Local-gov           0.295599
# Self-emp-not-inc    0.278871
# State-gov           0.267542
# Private             0.217867
# Without-pay         0.095238
# ?                   0.094677
# Never-worked        0.000000
# Name: income, dtype: float64

# %% [markdown]
# # How has better chance to get income >50k Male or Female

# %%
df.groupby('gender')['income'].mean().sort_values(ascending=False)
# Out:
# gender
# Male      0.303767
# Female    0.109251
# Name: income, dtype: float64

# %% [markdown]
# # Convert workclass columns Datatyppes  to Category datatype

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  int64
# dtypes: int64(7), object(8)
# memory usage: 5.6+ MB

# %%
df['workclass']=df['workclass'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  category
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  int64
# dtypes: category(1), int64(7), object(7)
# memory usage: 5.3+ MB

# %% [markdown]
# # End of Project

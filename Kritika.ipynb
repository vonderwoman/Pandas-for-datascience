# %%
import pandas as pd
import os

# %%
df=pd.read_csv("Faculty.csv")

# %%
df
# Out:
#                               Universities  Global Rank  \
# 0                                     BSBI            6
# 1           Technische Universität München            7
# 2   Ludwig-Maximilians-Universität München            8
# 3    Ruprecht-Karls-Universität Heidelberg            9
# 4                         Arden University           10
# 5                       Bremen  University           11
# 6                       Hamburg University           12
# 7                     Universitat Freiburg           13
# 8                          Eberhard Karls            14
# 9                       Munchen University           15
# 10                      Dresden University           16
# 11           Technische Universität Berlin           17
# 12           Technische Universität Bremen           18
# 13          Technische Universität Harburg           19
# 14           Technische Universität Berlin           20
# 15           Technische Universität Berlin           21
# ...

# %%
#Adding the 6th column which is the total of the faculties

# %%
#Introducing a new series of data frame called Business Maths Faculty

# %%
#creating the new column
df['Business Maths Faculty'] =df['CS Faculty'] + df['HR Faculty'] + df['BA Faculty'] + df['IR Faculty'] + df['SC Faculty']

# %%
df
# Out:
#                               Universities  Global Rank  \
# 0                                     BSBI            6
# 1           Technische Universität München            7
# 2   Ludwig-Maximilians-Universität München            8
# 3    Ruprecht-Karls-Universität Heidelberg            9
# 4                         Arden University           10
# 5                       Bremen  University           11
# 6                       Hamburg University           12
# 7                     Universitat Freiburg           13
# 8                          Eberhard Karls            14
# 9                       Munchen University           15
# 10                      Dresden University           16
# 11           Technische Universität Berlin           17
# 12           Technische Universität Bremen           18
# 13          Technische Universität Harburg           19
# 14           Technische Universität Berlin           20
# 15           Technische Universität Berlin           21
# ...

# %%
#all the mean,standard dievation
df.describe()
# Out:
#        Global Rank  Year of Establishment  CS Faculty  HR Faculty  BA Faculty  \
# count    21.000000              21.000000   21.000000   21.000000   21.000000
# mean     16.000000            1886.000000   88.000000   77.000000   30.000000
# std       6.204837               6.204837    6.204837    6.204837    6.204837
# min       6.000000            1876.000000   78.000000   67.000000   20.000000
# 25%      11.000000            1881.000000   83.000000   72.000000   25.000000
# 50%      16.000000            1886.000000   88.000000   77.000000   30.000000
# 75%      21.000000            1891.000000   93.000000   82.000000   35.000000
# max      26.000000            1896.000000   98.000000   87.000000   40.000000
#
#        IR Faculty  SC Faculty  Business Maths Faculty
# count   21.000000   21.000000               21.000000
# mean    20.000000   16.000000              231.000000
# std      6.204837    6.204837               31.024184
# ...

# %%
#grab specific columns
df[['CS Faculty','HR Faculty','IR Faculty']]
# Out:
#     CS Faculty  HR Faculty  IR Faculty
# 0           78          67          10
# 1           79          68          11
# 2           80          69          12
# 3           81          70          13
# 4           82          71          14
# 5           83          72          15
# 6           84          73          16
# 7           85          74          17
# 8           86          75          18
# 9           87          76          19
# 10          88          77          20
# 11          89          78          21
# 12          90          79          22
# 13          91          80          23
# 14          92          81          24
# 15          93          82          25
# 16          94          83          26
# 17          95          84          27
# 18          96          85          28
# 19          97          86          29
# 20          98          87          30

# %%
 cols=list(df.columns.values)

# %%
cols[4:3]
# Out:
# []

# %%
df
# Out:
#                               Universities  Global Rank  \
# 0                                     BSBI            6
# 1           Technische Universität München            7
# 2   Ludwig-Maximilians-Universität München            8
# 3    Ruprecht-Karls-Universität Heidelberg            9
# 4                         Arden University           10
# 5                       Bremen  University           11
# 6                       Hamburg University           12
# 7                     Universitat Freiburg           13
# 8                          Eberhard Karls            14
# 9                       Munchen University           15
# 10                      Dresden University           16
# 11           Technische Universität Berlin           17
# 12           Technische Universität Bremen           18
# 13          Technische Universität Harburg           19
# 14           Technische Universität Berlin           20
# 15           Technische Universität Berlin           21
# ...

# %%
#end of project
